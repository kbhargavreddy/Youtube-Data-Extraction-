# %%
import pandas as pd
df=pd.read_csv("/content/YOutubedata.csv")
df.describe()
# Out:
#         Unnamed: 0
# count  6048.000000
# mean   3023.500000
# std    1746.051546
# min       0.000000
# 25%    1511.750000
# 50%    3023.500000
# 75%    4535.250000
# max    6047.000000

# %%
df.head()
# Out:
#    Unnamed: 0     video_id                                              title  \
# 0           0  cqSMW2Haaww                          So that’s where that was!
# 1           1  KcHaN47U2ms  Firebase’s Release Monitoring dashboard, Dart ...
# 2           2  6LT3VcW9uCo              Ready by the next sprint? For sure. 🥴
# 3           3  hsf9ELHjieU  DevFest Dublin: What’s the best part about thi...
# 4           4  ydKbOv-FqiE     Growing together as a GDSC lead - Ishnoor Kaur
#
#                                          description          published_at  \
# 0  You never know what you’re going to find in a ...  2024-03-05T02:00:25Z
# 1  TL;DR 380  | The Google Developer News Show\n\...  2024-03-04T22:00:14Z
# 2  It happens when your suggestion is just THAT g...  2024-03-04T14:00:08Z
# 3  Curious about who brings DevFest Dublin to lif...  2024-03-01T20:00:16Z
# 4  In this video, Ishnoor Kaur details her time a...  2024-03-01T14:00:50Z
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6048 entries, 0 to 6047
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     6048 non-null   int64
#  1   video_id       6048 non-null   object
#  2   title          6048 non-null   object
#  3   description    5956 non-null   object
#  4   published_at   6048 non-null   object
#  5   thumbnail_url  6048 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 283.6+ KB

# %%
df.tail()
# Out:
#       Unnamed: 0     video_id                                      title  \
# 6043        6043  5Eib_H_zCEY  Cluster Computing and MapReduce Lecture 3
# 6044        6044  yjPBkvYh-ss  Cluster Computing and MapReduce Lecture 1
# 6045        6045  -vD6PUdf3Js  Cluster Computing and MapReduce Lecture 2
# 6046        6046  1ZDybXl212Q  Cluster Computing and MapReduce Lecture 4
# 6047        6047  F59KmOrnFco               Gearing up with Zoho Offline
#
#                                             description          published_at  \
# 6043  Lecture 3: The Google File System. See\r\nhttp...  2007-08-28T16:56:29Z
# 6044  Lecture 1 in a five part series introducing ma...  2007-08-28T16:53:57Z
# 6045  Lecture 2: The MapReduce programming model. Se...  2007-08-28T16:51:42Z
# 6046  Lecture 4: Clustering Algorithms with MapReduc...  2007-08-28T16:46:15Z
# 6047  An interview with the Zoho team on their offli...  2007-08-23T17:44:51Z
#
#                                        thumbnail_url
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# video_id         object
# title            object
# description      object
# published_at     object
# thumbnail_url    object
# dtype: object

# %%
D=df["published_at"]
Dates=[]
for i in D:
  Dates.append(i[0:10])

df.drop(["published_at"],axis=1,inplace=True)
df["Dates"]=Dates
df
# Out:
#       Unnamed: 0     video_id  \
# 0              0  cqSMW2Haaww
# 1              1  KcHaN47U2ms
# 2              2  6LT3VcW9uCo
# 3              3  hsf9ELHjieU
# 4              4  ydKbOv-FqiE
# ...          ...          ...
# 6043        6043  5Eib_H_zCEY
# 6044        6044  yjPBkvYh-ss
# 6045        6045  -vD6PUdf3Js
# 6046        6046  1ZDybXl212Q
# 6047        6047  F59KmOrnFco
#
#                                                   title  \
# 0                             So that’s where that was!
# 1     Firebase’s Release Monitoring dashboard, Dart ...
# 2                 Ready by the next sprint? For sure. 🥴
# 3     DevFest Dublin: What’s the best part about thi...
# 4        Growing together as a GDSC lead - Ishnoor Kaur
# ...                                                 ...
# 6043          Cluster Computing and MapReduce Lecture 3
# 6044          Cluster Computing and MapReduce Lecture 1
# 6045          Cluster Computing and MapReduce Lecture 2
# ...

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df
# Out:
#          video_id                                              title  \
# 0     cqSMW2Haaww                          So that’s where that was!
# 1     KcHaN47U2ms  Firebase’s Release Monitoring dashboard, Dart ...
# 2     6LT3VcW9uCo              Ready by the next sprint? For sure. 🥴
# 3     hsf9ELHjieU  DevFest Dublin: What’s the best part about thi...
# 4     ydKbOv-FqiE     Growing together as a GDSC lead - Ishnoor Kaur
# ...           ...                                                ...
# 6043  5Eib_H_zCEY          Cluster Computing and MapReduce Lecture 3
# 6044  yjPBkvYh-ss          Cluster Computing and MapReduce Lecture 1
# 6045  -vD6PUdf3Js          Cluster Computing and MapReduce Lecture 2
# 6046  1ZDybXl212Q          Cluster Computing and MapReduce Lecture 4
# 6047  F59KmOrnFco                       Gearing up with Zoho Offline
#
#                                             description  \
# 0     You never know what you’re going to find in a ...
# ...
